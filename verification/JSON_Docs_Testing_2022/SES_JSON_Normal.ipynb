# %% [markdown]
# # SES Dataset Processing with JSON and Python
#
# ![Ses1.ico]SES Image
#
# ## Setup connection to SES json file:
# - start by importing the standard json module
# - open an SES json file.  Use utf-8 to stick with ascii.
# - load the entire json file into a json list of json objects that are created as the SES program runs.
# - The current types of objects in this list are:
# - > 'info'
# - > 'pit'

# %%
import json

# point to json file created by ses and open it
json_file = open("TestSESCases/normal.json","r", encoding='utf-8')

my_dataset = json.load(json_file)
# print out the type of the dataset object ... should be list 
print("type of my_dataset:", type(my_dataset))

clean_str = json.dumps(my_dataset, indent=1)
# Out:
# type of my_dataset: <class 'list'>

# %%
print(clean_str)
# the first object is for information like utc time of run start and 
# other dataset meta-data.  this object is not complete at this time.
# until it is an empty dictionary is created in it's place.
# Out:
# [
#  {
#   "info": {}
#  },
#  {
#   "pit": 0.0,
#   "train_data": [
#    {
#     "train_id": 1,
#     "train_short_id": " 1",
#     "type": 1,
#     "route": 1,
#     "position": 2877.21,
#     "velocity": 19.25,
#     "acceleration": 3.0,
#     "mode": 2,
#     "total_drag": 1521.01,
#     "air_drag": 0.0,
#     "tractive_effort": 5412.26,
#     "drag_coefficient": 0.0,
#     "motor_current": 900.0,
#     "line_current": 959.0,
#     "flywheel_speed": 0.0,
#     "accel_grid_temperature": 276.0,
#     "decel_grid_temperature": 740.1,
#     "heat_generated": 0.434,
#     "heat_rejected": 0.434,
#     "aux_power": 349000.0,
#     "propulsion_power": 0.0,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 0.0,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 0.0,
#     "propulsion_heat_released": 0.0,
#     "aux_heat_released_sensible": 0.434,
#     "aux_heat_released_latent": 0.0502,
#     "passengers": 450
#    },
#    {
#     "train_id": 2,
#     "train_short_id": " 2",
#     "type": 2,
#     "route": 2,
#     "position": 2744.71,
#     "velocity": 11.0,
#     "acceleration": 3.0,
#     "mode": 2,
#     "total_drag": 1385.72,
#     "air_drag": 0.0,
#     "tractive_effort": 6692.62,
#     "drag_coefficient": 0.0,
#     "motor_current": 900.0,
#     "line_current": 755.78,
#     "flywheel_speed": 10000.0,
#     "accel_grid_temperature": 241.6,
#     "decel_grid_temperature": 751.3,
#     "heat_generated": 0.369,
#     "heat_rejected": 0.369,
#     "aux_power": 324000.0,
#     "propulsion_power": 0.0,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 0.0,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 0.0,
#     "propulsion_heat_released": 0.0,
#     "aux_heat_released_sensible": 0.369,
#     "aux_heat_released_latent": 0.0223,
#     "passengers": 200
#    }
#   ],
#   "section_data": [
#    {
#     "section_id": 1,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 2,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 3,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 4,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 5,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 6,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 7,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 8,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 9,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 10,
#     "airflow_rate": 0.0,
#     "buoyancy": -0.00043,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 11,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 12,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 13,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 14,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    },
#    {
#     "section_id": 15,
#     "airflow_rate": 0.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0
#    }
#   ],
#   "segment_data": [
#    {
#     "segment_id": "1 -  1",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  2",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  3",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "2 -  4",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "3 -103",
#     "line": false,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0
#    },
#    {
#     "segment_id": "4 -104",
#     "line": false,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0
#    },
#    {
#     "segment_id": "5 -  5",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "6 -  6",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "7 -  7",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "8 -  8",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "9 -  9",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "10 -110",
#     "line": false,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0
#    },
#    {
#     "segment_id": "11 - 10",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "12 - 11",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "13 - 12",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "14 -114",
#     "line": false,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0
#    },
#    {
#     "segment_id": "15 - 13",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "15 - 14",
#     "line": true,
#     "air_velocity": 0.0,
#     "reynolds_number": 0.0,
#     "number_of_trains": 0
#    }
#   ],
#   "subsegment_data": [
#    {
#     "subsegment_id": "1 -  1 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.194,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  2 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.194,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.389,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.389,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.45,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.45,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  3",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.45,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "3 -103 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.03149,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "4 -104 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.389,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.389,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  3",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.389,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.45,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.45,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  3",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.45,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "7 -  7 -  1",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0001219,
#     "sensible_heat_load": 32.574,
#     "latent_heat_load": 11.66,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "8 -  8 -  1",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 5.83e-05,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "8 -  8 -  2",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 5.83e-05,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  1",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0002001,
#     "sensible_heat_load": 86.11,
#     "latent_heat_load": 17.903,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  2",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0002,
#     "sensible_heat_load": 93.572,
#     "latent_heat_load": 18.767,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  3",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0002,
#     "sensible_heat_load": 93.572,
#     "latent_heat_load": 18.767,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  4",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0002,
#     "sensible_heat_load": 93.572,
#     "latent_heat_load": 18.767,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "10 -110 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  1",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 5.83e-05,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  2",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 5.83e-05,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "12 - 11 -  1",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0002,
#     "sensible_heat_load": 95.864,
#     "latent_heat_load": 18.385,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0002643,
#     "sensible_heat_load": 39.701,
#     "latent_heat_load": 5.999,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.366,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  3",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.366,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "14 -114 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 13 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.839,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 13 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.839,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 14 -  1",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.129,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 14 -  2",
#     "air_temperature": 90.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02017,
#     "heat_transfer_coeff": 0.0,
#     "sensible_heat_load": 2.129,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    }
#   ]
#  },
#  {
#   "pit": 180.0,
#   "train_data": [
#    {
#     "train_id": 5,
#     "train_short_id": " 5",
#     "type": 1,
#     "route": 1,
#     "position": 2787.13,
#     "velocity": 5.4,
#     "acceleration": 3.0,
#     "mode": 2,
#     "total_drag": 1454.69,
#     "air_drag": 109.56,
#     "tractive_effort": 5165.87,
#     "drag_coefficient": 15.79,
#     "motor_current": 790.71,
#     "line_current": 299.0,
#     "flywheel_speed": 0.0,
#     "accel_grid_temperature": 90.0,
#     "decel_grid_temperature": 611.9,
#     "heat_generated": 0.885,
#     "heat_rejected": 1.413,
#     "aux_power": 349000.0,
#     "propulsion_power": 1435220.38,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 238.895,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 13.747,
#     "propulsion_heat_released": 0.98,
#     "aux_heat_released_sensible": 0.434,
#     "aux_heat_released_latent": 0.0502,
#     "passengers": 450
#    },
#    {
#     "train_id": 6,
#     "train_short_id": " 6",
#     "type": 2,
#     "route": 2,
#     "position": 2636.93,
#     "velocity": 23.2,
#     "acceleration": -2.76,
#     "mode": 4,
#     "total_drag": 3818.79,
#     "air_drag": 44.52,
#     "tractive_effort": 0.0,
#     "drag_coefficient": 0.35,
#     "motor_current": 0.0,
#     "line_current": 0.0,
#     "flywheel_speed": 12996.719,
#     "accel_grid_temperature": 90.0,
#     "decel_grid_temperature": 571.92,
#     "heat_generated": 1.555,
#     "heat_rejected": 2.182,
#     "aux_power": 324000.0,
#     "propulsion_power": 0.0,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 597.184,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 66.736,
#     "propulsion_heat_released": 1.813,
#     "aux_heat_released_sensible": 0.369,
#     "aux_heat_released_latent": 0.0223,
#     "passengers": 200
#    }
#   ],
#   "section_data": [
#    {
#     "section_id": 1,
#     "airflow_rate": 39728.4,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05727
#    },
#    {
#     "section_id": 2,
#     "airflow_rate": -318522.1,
#     "buoyancy": 0.0,
#     "pressure_change": 0.02374
#    },
#    {
#     "section_id": 3,
#     "airflow_rate": 99522.8,
#     "buoyancy": 0.00085,
#     "pressure_change": -0.04558
#    },
#    {
#     "section_id": 4,
#     "airflow_rate": -15568.9,
#     "buoyancy": 0.00128,
#     "pressure_change": 0.01689
#    },
#    {
#     "section_id": 5,
#     "airflow_rate": -59794.5,
#     "buoyancy": 0.0,
#     "pressure_change": -0.22915
#    },
#    {
#     "section_id": 6,
#     "airflow_rate": -302953.2,
#     "buoyancy": 0.0,
#     "pressure_change": -0.24697
#    },
#    {
#     "section_id": 7,
#     "airflow_rate": -362747.7,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05818
#    },
#    {
#     "section_id": 8,
#     "airflow_rate": 15555.9,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04757
#    },
#    {
#     "section_id": 9,
#     "airflow_rate": -378303.6,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05183
#    },
#    {
#     "section_id": 10,
#     "airflow_rate": -35694.4,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04698
#    },
#    {
#     "section_id": 11,
#     "airflow_rate": 51250.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.00495
#    },
#    {
#     "section_id": 12,
#     "airflow_rate": -327053.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05382
#    },
#    {
#     "section_id": 13,
#     "airflow_rate": -327053.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04495
#    },
#    {
#     "section_id": 14,
#     "airflow_rate": 138298.3,
#     "buoyancy": 0.00256,
#     "pressure_change": 0.02507
#    },
#    {
#     "section_id": 15,
#     "airflow_rate": -465351.6,
#     "buoyancy": 0.0,
#     "pressure_change": -0.05509
#    }
#   ],
#   "segment_data": [
#    {
#     "segment_id": "1 -  1",
#     "line": true,
#     "air_velocity": 132.4,
#     "reynolds_number": 213710.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  2",
#     "line": true,
#     "air_velocity": 158.9,
#     "reynolds_number": 230120.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  3",
#     "line": true,
#     "air_velocity": 176.6,
#     "reynolds_number": 241080.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "2 -  4",
#     "line": true,
#     "air_velocity": -1415.7,
#     "reynolds_number": 1932900.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "3 -103",
#     "line": false,
#     "air_velocity": 497.6,
#     "reynolds_number": 612990.0
#    },
#    {
#     "segment_id": "4 -104",
#     "line": false,
#     "air_velocity": -117.3,
#     "reynolds_number": 129540.0
#    },
#    {
#     "segment_id": "5 -  5",
#     "line": true,
#     "air_velocity": -265.8,
#     "reynolds_number": 362850.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "6 -  6",
#     "line": true,
#     "air_velocity": -1346.5,
#     "reynolds_number": 1838400.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "7 -  7",
#     "line": true,
#     "air_velocity": -518.2,
#     "reynolds_number": 1142900.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "8 -  8",
#     "line": true,
#     "air_velocity": 34.6,
#     "reynolds_number": 67713.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "9 -  9",
#     "line": true,
#     "air_velocity": -540.4,
#     "reynolds_number": 1191900.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "10 -110",
#     "line": false,
#     "air_velocity": -369.9,
#     "reynolds_number": 329780.0
#    },
#    {
#     "segment_id": "11 - 10",
#     "line": true,
#     "air_velocity": 113.9,
#     "reynolds_number": 223090.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "12 - 11",
#     "line": true,
#     "air_velocity": -467.2,
#     "reynolds_number": 1030400.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "13 - 12",
#     "line": true,
#     "air_velocity": -817.6,
#     "reynolds_number": 1533800.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "14 -114",
#     "line": false,
#     "air_velocity": 921.8,
#     "reynolds_number": 1090700.0
#    },
#    {
#     "segment_id": "15 - 13",
#     "line": true,
#     "air_velocity": -1163.4,
#     "reynolds_number": 2182400.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "15 - 14",
#     "line": true,
#     "air_velocity": -664.8,
#     "reynolds_number": 1466100.0,
#     "number_of_trains": 0
#    }
#   ],
#   "subsegment_data": [
#    {
#     "subsegment_id": "1 -  1 -  1",
#     "air_temperature": 89.98,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.0001095,
#     "sensible_heat_load": -0.19,
#     "latent_heat_load": 0.385,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  2 -  1",
#     "air_temperature": 89.97,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.0001325,
#     "sensible_heat_load": -0.237,
#     "latent_heat_load": 0.432,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  1",
#     "air_temperature": 90.09,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.0202,
#     "heat_transfer_coeff": 0.0001473,
#     "sensible_heat_load": -0.532,
#     "latent_heat_load": 0.924,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  2",
#     "air_temperature": 90.5,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0001473,
#     "sensible_heat_load": -0.558,
#     "latent_heat_load": 0.95,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  1",
#     "air_temperature": 94.1,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.0188,
#     "heat_transfer_coeff": 0.0009676,
#     "sensible_heat_load": -4.933,
#     "latent_heat_load": 8.729,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  2",
#     "air_temperature": 94.06,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01884,
#     "heat_transfer_coeff": 0.0009676,
#     "sensible_heat_load": -4.894,
#     "latent_heat_load": 8.689,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  3",
#     "air_temperature": 94.06,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01872,
#     "heat_transfer_coeff": 0.0009676,
#     "sensible_heat_load": -4.959,
#     "latent_heat_load": 8.754,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "3 -103 -  1",
#     "air_temperature": 90.69,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0002474,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "4 -104 -  1",
#     "air_temperature": 90.08,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02002,
#     "heat_transfer_coeff": 7.96e-05,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  1",
#     "air_temperature": 91.39,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02027,
#     "heat_transfer_coeff": 0.0002139,
#     "sensible_heat_load": -1.065,
#     "latent_heat_load": 1.463,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  2",
#     "air_temperature": 92.22,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02027,
#     "heat_transfer_coeff": 0.0002139,
#     "sensible_heat_load": -1.147,
#     "latent_heat_load": 1.545,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  3",
#     "air_temperature": 93.41,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01982,
#     "heat_transfer_coeff": 0.0002139,
#     "sensible_heat_load": -1.326,
#     "latent_heat_load": 1.724,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  1",
#     "air_temperature": 94.2,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01834,
#     "heat_transfer_coeff": 0.0009253,
#     "sensible_heat_load": -5.049,
#     "latent_heat_load": 8.656,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  2",
#     "air_temperature": 94.33,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01778,
#     "heat_transfer_coeff": 0.0009253,
#     "sensible_heat_load": -5.432,
#     "latent_heat_load": 9.04,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  3",
#     "air_temperature": 94.84,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01713,
#     "heat_transfer_coeff": 0.0009253,
#     "sensible_heat_load": -6.038,
#     "latent_heat_load": 9.646,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "7 -  7 -  1",
#     "air_temperature": 95.54,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01673,
#     "heat_transfer_coeff": 0.0005593,
#     "sensible_heat_load": 99.648,
#     "latent_heat_load": 19.523,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "8 -  8 -  1",
#     "air_temperature": 91.58,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01767,
#     "heat_transfer_coeff": 0.0001146,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "8 -  8 -  2",
#     "air_temperature": 91.1,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01878,
#     "heat_transfer_coeff": 0.0001121,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  1",
#     "air_temperature": 95.73,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01674,
#     "heat_transfer_coeff": 0.000594,
#     "sensible_heat_load": 197.169,
#     "latent_heat_load": 22.501,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  2",
#     "air_temperature": 96.27,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01708,
#     "heat_transfer_coeff": 0.0004884,
#     "sensible_heat_load": 313.046,
#     "latent_heat_load": 22.795,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  3",
#     "air_temperature": 96.8,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01761,
#     "heat_transfer_coeff": 0.0004884,
#     "sensible_heat_load": 313.09,
#     "latent_heat_load": 22.752,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  4",
#     "air_temperature": 96.97,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01815,
#     "heat_transfer_coeff": 0.0004884,
#     "sensible_heat_load": 313.213,
#     "latent_heat_load": 22.628,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "10 -110 -  1",
#     "air_temperature": 90.48,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01922,
#     "heat_transfer_coeff": 0.0002082,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  1",
#     "air_temperature": 91.28,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01794,
#     "heat_transfer_coeff": 0.0001131,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  2",
#     "air_temperature": 92.4,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01733,
#     "heat_transfer_coeff": 0.0001186,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "12 - 11 -  1",
#     "air_temperature": 97.83,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01889,
#     "heat_transfer_coeff": 0.000376,
#     "sensible_heat_load": 300.995,
#     "latent_heat_load": 20.415,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  1",
#     "air_temperature": 99.58,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01943,
#     "heat_transfer_coeff": 0.000483,
#     "sensible_heat_load": 265.352,
#     "latent_heat_load": 8.587,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  2",
#     "air_temperature": 97.97,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01992,
#     "heat_transfer_coeff": 0.0005513,
#     "sensible_heat_load": -3.419,
#     "latent_heat_load": 6.048,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  3",
#     "air_temperature": 95.52,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02016,
#     "heat_transfer_coeff": 0.0005513,
#     "sensible_heat_load": -2.641,
#     "latent_heat_load": 5.27,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "14 -114 -  1",
#     "air_temperature": 93.72,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0004084,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 13 -  1",
#     "air_temperature": 93.29,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0007549,
#     "sensible_heat_load": -3.839,
#     "latent_heat_load": 7.586,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 13 -  2",
#     "air_temperature": 92.02,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02021,
#     "heat_transfer_coeff": 0.0007549,
#     "sensible_heat_load": -3.263,
#     "latent_heat_load": 7.01,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 14 -  1",
#     "air_temperature": 91.16,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02019,
#     "heat_transfer_coeff": 0.00044,
#     "sensible_heat_load": -1.997,
#     "latent_heat_load": 4.309,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 14 -  2",
#     "air_temperature": 90.4,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.00044,
#     "sensible_heat_load": -1.776,
#     "latent_heat_load": 4.087,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    }
#   ]
#  },
#  {
#   "pit": 270.0,
#   "train_data": [
#    {
#     "train_id": 7,
#     "train_short_id": " 7",
#     "type": 1,
#     "route": 1,
#     "position": 2787.13,
#     "velocity": 5.4,
#     "acceleration": 3.0,
#     "mode": 2,
#     "total_drag": 1454.61,
#     "air_drag": 109.48,
#     "tractive_effort": 5165.87,
#     "drag_coefficient": 15.78,
#     "motor_current": 790.71,
#     "line_current": 299.0,
#     "flywheel_speed": 0.0,
#     "accel_grid_temperature": 90.0,
#     "decel_grid_temperature": 610.38,
#     "heat_generated": 0.885,
#     "heat_rejected": 1.388,
#     "aux_power": 349000.0,
#     "propulsion_power": 1435219.0,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 238.895,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 13.747,
#     "propulsion_heat_released": 0.955,
#     "aux_heat_released_sensible": 0.434,
#     "aux_heat_released_latent": 0.0502,
#     "passengers": 450
#    },
#    {
#     "train_id": 8,
#     "train_short_id": " 8",
#     "type": 2,
#     "route": 2,
#     "position": 2636.93,
#     "velocity": 23.2,
#     "acceleration": -2.76,
#     "mode": 4,
#     "total_drag": 3818.92,
#     "air_drag": 44.64,
#     "tractive_effort": 0.0,
#     "drag_coefficient": 0.35,
#     "motor_current": 0.0,
#     "line_current": 0.0,
#     "flywheel_speed": 13042.873,
#     "accel_grid_temperature": 90.0,
#     "decel_grid_temperature": 571.97,
#     "heat_generated": 1.555,
#     "heat_rejected": 2.203,
#     "aux_power": 324000.0,
#     "propulsion_power": 0.0,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 597.348,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 66.736,
#     "propulsion_heat_released": 1.834,
#     "aux_heat_released_sensible": 0.369,
#     "aux_heat_released_latent": 0.0223,
#     "passengers": 200
#    }
#   ],
#   "section_data": [
#    {
#     "section_id": 1,
#     "airflow_rate": 39943.9,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05704
#    },
#    {
#     "section_id": 2,
#     "airflow_rate": -318275.2,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0232
#    },
#    {
#     "section_id": 3,
#     "airflow_rate": 99357.8,
#     "buoyancy": 0.00085,
#     "pressure_change": -0.04542
#    },
#    {
#     "section_id": 4,
#     "airflow_rate": -15338.1,
#     "buoyancy": 0.00213,
#     "pressure_change": 0.01752
#    },
#    {
#     "section_id": 5,
#     "airflow_rate": -59413.9,
#     "buoyancy": 0.0,
#     "pressure_change": -0.2293
#    },
#    {
#     "section_id": 6,
#     "airflow_rate": -302937.1,
#     "buoyancy": 0.0,
#     "pressure_change": -0.24671
#    },
#    {
#     "section_id": 7,
#     "airflow_rate": -362351.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05809
#    },
#    {
#     "section_id": 8,
#     "airflow_rate": 15602.1,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04756
#    },
#    {
#     "section_id": 9,
#     "airflow_rate": -377953.0,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05179
#    },
#    {
#     "section_id": 10,
#     "airflow_rate": -35720.1,
#     "buoyancy": 0.00043,
#     "pressure_change": 0.04744
#    },
#    {
#     "section_id": 11,
#     "airflow_rate": 51322.2,
#     "buoyancy": 0.0,
#     "pressure_change": 0.00493
#    },
#    {
#     "section_id": 12,
#     "airflow_rate": -326630.9,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05384
#    },
#    {
#     "section_id": 13,
#     "airflow_rate": -326630.9,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04522
#    },
#    {
#     "section_id": 14,
#     "airflow_rate": 138297.2,
#     "buoyancy": 0.00256,
#     "pressure_change": 0.02512
#    },
#    {
#     "section_id": 15,
#     "airflow_rate": -464928.1,
#     "buoyancy": 0.0,
#     "pressure_change": -0.05488
#    }
#   ],
#   "segment_data": [
#    {
#     "segment_id": "1 -  1",
#     "line": true,
#     "air_velocity": 133.1,
#     "reynolds_number": 214870.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  2",
#     "line": true,
#     "air_velocity": 159.8,
#     "reynolds_number": 231370.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  3",
#     "line": true,
#     "air_velocity": 177.5,
#     "reynolds_number": 242390.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "2 -  4",
#     "line": true,
#     "air_velocity": -1414.6,
#     "reynolds_number": 1931400.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "3 -103",
#     "line": false,
#     "air_velocity": 496.8,
#     "reynolds_number": 611980.0
#    },
#    {
#     "segment_id": "4 -104",
#     "line": false,
#     "air_velocity": -115.6,
#     "reynolds_number": 127620.0
#    },
#    {
#     "segment_id": "5 -  5",
#     "line": true,
#     "air_velocity": -264.1,
#     "reynolds_number": 360540.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "6 -  6",
#     "line": true,
#     "air_velocity": -1346.4,
#     "reynolds_number": 1838300.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "7 -  7",
#     "line": true,
#     "air_velocity": -517.6,
#     "reynolds_number": 1141600.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "8 -  8",
#     "line": true,
#     "air_velocity": 34.7,
#     "reynolds_number": 67914.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "9 -  9",
#     "line": true,
#     "air_velocity": -539.9,
#     "reynolds_number": 1190800.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "10 -110",
#     "line": false,
#     "air_velocity": -370.2,
#     "reynolds_number": 330020.0
#    },
#    {
#     "segment_id": "11 - 10",
#     "line": true,
#     "air_velocity": 114.0,
#     "reynolds_number": 223400.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "12 - 11",
#     "line": true,
#     "air_velocity": -466.6,
#     "reynolds_number": 1029100.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "13 - 12",
#     "line": true,
#     "air_velocity": -816.6,
#     "reynolds_number": 1531800.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "14 -114",
#     "line": false,
#     "air_velocity": 921.8,
#     "reynolds_number": 1090700.0
#    },
#    {
#     "segment_id": "15 - 13",
#     "line": true,
#     "air_velocity": -1162.3,
#     "reynolds_number": 2180400.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "15 - 14",
#     "line": true,
#     "air_velocity": -664.2,
#     "reynolds_number": 1464800.0,
#     "number_of_trains": 0
#    }
#   ],
#   "subsegment_data": [
#    {
#     "subsegment_id": "1 -  1 -  1",
#     "air_temperature": 89.98,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.0001109,
#     "sensible_heat_load": -0.195,
#     "latent_heat_load": 0.39,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  2 -  1",
#     "air_temperature": 89.97,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.0001342,
#     "sensible_heat_load": -0.242,
#     "latent_heat_load": 0.437,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  1",
#     "air_temperature": 90.09,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.0202,
#     "heat_transfer_coeff": 0.0001492,
#     "sensible_heat_load": -0.543,
#     "latent_heat_load": 0.935,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  2",
#     "air_temperature": 90.49,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0001492,
#     "sensible_heat_load": -0.57,
#     "latent_heat_load": 0.961,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  1",
#     "air_temperature": 95.11,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01901,
#     "heat_transfer_coeff": 0.0009682,
#     "sensible_heat_load": -5.276,
#     "latent_heat_load": 9.074,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  2",
#     "air_temperature": 95.16,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01914,
#     "heat_transfer_coeff": 0.0009682,
#     "sensible_heat_load": -5.218,
#     "latent_heat_load": 9.016,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  3",
#     "air_temperature": 95.37,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01916,
#     "heat_transfer_coeff": 0.0009682,
#     "sensible_heat_load": -5.299,
#     "latent_heat_load": 9.097,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "3 -103 -  1",
#     "air_temperature": 90.69,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02022,
#     "heat_transfer_coeff": 0.0002478,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "4 -104 -  1",
#     "air_temperature": 90.21,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02003,
#     "heat_transfer_coeff": 7.75e-05,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  1",
#     "air_temperature": 91.39,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02026,
#     "heat_transfer_coeff": 0.0002128,
#     "sensible_heat_load": -1.059,
#     "latent_heat_load": 1.457,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  2",
#     "air_temperature": 92.27,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02026,
#     "heat_transfer_coeff": 0.0002128,
#     "sensible_heat_load": -1.146,
#     "latent_heat_load": 1.543,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  3",
#     "air_temperature": 94.0,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.02001,
#     "heat_transfer_coeff": 0.0002128,
#     "sensible_heat_load": -1.351,
#     "latent_heat_load": 1.748,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  1",
#     "air_temperature": 95.97,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.019,
#     "heat_transfer_coeff": 0.0009273,
#     "sensible_heat_load": -5.442,
#     "latent_heat_load": 9.058,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  2",
#     "air_temperature": 96.75,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01876,
#     "heat_transfer_coeff": 0.0009273,
#     "sensible_heat_load": -5.918,
#     "latent_heat_load": 9.534,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  3",
#     "air_temperature": 98.06,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01848,
#     "heat_transfer_coeff": 0.0009273,
#     "sensible_heat_load": -6.647,
#     "latent_heat_load": 10.263,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "7 -  7 -  1",
#     "air_temperature": 99.41,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.0184,
#     "heat_transfer_coeff": 0.0005596,
#     "sensible_heat_load": 98.709,
#     "latent_heat_load": 19.97,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "8 -  8 -  1",
#     "air_temperature": 93.6,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01857,
#     "heat_transfer_coeff": 0.000124,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "8 -  8 -  2",
#     "air_temperature": 92.04,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01931,
#     "heat_transfer_coeff": 0.0001169,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  1",
#     "air_temperature": 99.6,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01859,
#     "heat_transfer_coeff": 0.0005974,
#     "sensible_heat_load": 189.091,
#     "latent_heat_load": 22.832,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  2",
#     "air_temperature": 99.81,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01889,
#     "heat_transfer_coeff": 0.000483,
#     "sensible_heat_load": 312.514,
#     "latent_heat_load": 22.978,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  3",
#     "air_temperature": 99.77,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01921,
#     "heat_transfer_coeff": 0.000483,
#     "sensible_heat_load": 312.611,
#     "latent_heat_load": 22.881,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "9 -  9 -  4",
#     "air_temperature": 99.3,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01945,
#     "heat_transfer_coeff": 0.000483,
#     "sensible_heat_load": 312.783,
#     "latent_heat_load": 22.709,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "10 -110 -  1",
#     "air_temperature": 91.18,
#     "wall_temperature": 90.0,
#     "humidity_ratio": 0.01957,
#     "heat_transfer_coeff": 0.0002062,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  1",
#     "air_temperature": 92.91,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01879,
#     "heat_transfer_coeff": 0.0001209,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  2",
#     "air_temperature": 94.86,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01856,
#     "heat_transfer_coeff": 0.0001292,
#     "sensible_heat_load": 22.917,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "12 - 11 -  1",
#     "air_temperature": 99.39,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01983,
#     "heat_transfer_coeff": 0.0003676,
#     "sensible_heat_load": 300.011,
#     "latent_heat_load": 20.345,
# ...
#     "motor_current": 0.0,
#     "line_current": 0.0,
#     "flywheel_speed": 12996.67,
#     "accel_grid_temperature": 90.0,
#     "decel_grid_temperature": 571.77,
#     "heat_generated": 1.555,
#     "heat_rejected": 2.266,
#     "aux_power": 324000.0,
#     "propulsion_power": 0.0,
#     "regeneration_power": 0.0,
#     "flywheel_power": 0.0,
#     "accel_grid_heat_in": 597.182,
#     "decel_grid_heat_in": 0.0,
#     "rolling_resistance_heat": 66.734,
#     "propulsion_heat_released": 1.897,
#     "aux_heat_released_sensible": 0.369,
#     "aux_heat_released_latent": 0.0223,
#     "passengers": 200
#    }
#   ],
#   "section_data": [
#    {
#     "section_id": 1,
#     "airflow_rate": 37355.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05907
#    },
#    {
#     "section_id": 2,
#     "airflow_rate": -319836.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.02624
#    },
#    {
#     "section_id": 3,
#     "airflow_rate": 98071.0,
#     "buoyancy": -0.00341,
#     "pressure_change": -0.04758
#    },
#    {
#     "section_id": 4,
#     "airflow_rate": -16955.4,
#     "buoyancy": -0.00298,
#     "pressure_change": 0.01378
#    },
#    {
#     "section_id": 5,
#     "airflow_rate": -60715.8,
#     "buoyancy": 0.0,
#     "pressure_change": -0.22957
#    },
#    {
#     "section_id": 6,
#     "airflow_rate": -302880.9,
#     "buoyancy": 0.0,
#     "pressure_change": -0.2486
#    },
#    {
#     "section_id": 7,
#     "airflow_rate": -363596.7,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05904
#    },
#    {
#     "section_id": 8,
#     "airflow_rate": 17471.8,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04634
#    },
#    {
#     "section_id": 9,
#     "airflow_rate": -381068.5,
#     "buoyancy": 0.0,
#     "pressure_change": 0.04729
#    },
#    {
#     "section_id": 10,
#     "airflow_rate": -35768.3,
#     "buoyancy": -0.00128,
#     "pressure_change": 0.046
#    },
#    {
#     "section_id": 11,
#     "airflow_rate": 53240.1,
#     "buoyancy": 0.0,
#     "pressure_change": 0.00169
#    },
#    {
#     "section_id": 12,
#     "airflow_rate": -327828.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.05181
#    },
#    {
#     "section_id": 13,
#     "airflow_rate": -327828.3,
#     "buoyancy": 0.0,
#     "pressure_change": 0.0461
#    },
#    {
#     "section_id": 14,
#     "airflow_rate": 138177.8,
#     "buoyancy": 0.00043,
#     "pressure_change": 0.02851
#    },
#    {
#     "section_id": 15,
#     "airflow_rate": -466006.1,
#     "buoyancy": 0.0,
#     "pressure_change": -0.05187
#    }
#   ],
#   "segment_data": [
#    {
#     "segment_id": "1 -  1",
#     "line": true,
#     "air_velocity": 124.5,
#     "reynolds_number": 200950.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  2",
#     "line": true,
#     "air_velocity": 149.4,
#     "reynolds_number": 216380.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "1 -  3",
#     "line": true,
#     "air_velocity": 166.0,
#     "reynolds_number": 226680.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "2 -  4",
#     "line": true,
#     "air_velocity": -1421.5,
#     "reynolds_number": 1940900.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "3 -103",
#     "line": false,
#     "air_velocity": 490.4,
#     "reynolds_number": 604050.0
#    },
#    {
#     "segment_id": "4 -104",
#     "line": false,
#     "air_velocity": -127.7,
#     "reynolds_number": 141070.0
#    },
#    {
#     "segment_id": "5 -  5",
#     "line": true,
#     "air_velocity": -269.8,
#     "reynolds_number": 368440.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "6 -  6",
#     "line": true,
#     "air_velocity": -1346.1,
#     "reynolds_number": 1838000.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "7 -  7",
#     "line": true,
#     "air_velocity": -519.4,
#     "reynolds_number": 1145500.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "8 -  8",
#     "line": true,
#     "air_velocity": 38.8,
#     "reynolds_number": 76052.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "9 -  9",
#     "line": true,
#     "air_velocity": -544.4,
#     "reynolds_number": 1200600.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "10 -110",
#     "line": false,
#     "air_velocity": -370.7,
#     "reynolds_number": 330460.0
#    },
#    {
#     "segment_id": "11 - 10",
#     "line": true,
#     "air_velocity": 118.3,
#     "reynolds_number": 231750.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "12 - 11",
#     "line": true,
#     "air_velocity": -468.3,
#     "reynolds_number": 1032800.0,
#     "number_of_trains": 2
#    },
#    {
#     "segment_id": "13 - 12",
#     "line": true,
#     "air_velocity": -819.6,
#     "reynolds_number": 1537500.0,
#     "number_of_trains": 1
#    },
#    {
#     "segment_id": "14 -114",
#     "line": false,
#     "air_velocity": 921.0,
#     "reynolds_number": 1089700.0
#    },
#    {
#     "segment_id": "15 - 13",
#     "line": true,
#     "air_velocity": -1165.0,
#     "reynolds_number": 2185500.0,
#     "number_of_trains": 0
#    },
#    {
#     "segment_id": "15 - 14",
#     "line": true,
#     "air_velocity": -665.7,
#     "reynolds_number": 1468200.0,
#     "number_of_trains": 0
#    }
#   ],
#   "subsegment_data": [
#    {
#     "subsegment_id": "1 -  1 -  1",
#     "air_temperature": 89.61,
#     "wall_temperature": 79.79,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.0001241,
#     "sensible_heat_load": -0.223,
#     "latent_heat_load": 0.418,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  2 -  1",
#     "air_temperature": 89.22,
#     "wall_temperature": 80.06,
#     "humidity_ratio": 0.02019,
#     "heat_transfer_coeff": 0.0001274,
#     "sensible_heat_load": -0.185,
#     "latent_heat_load": 0.381,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  1",
#     "air_temperature": 88.65,
#     "wall_temperature": 80.14,
#     "humidity_ratio": 0.02021,
#     "heat_transfer_coeff": 0.0001416,
#     "sensible_heat_load": -0.356,
#     "latent_heat_load": 0.747,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "1 -  3 -  2",
#     "air_temperature": 88.36,
#     "wall_temperature": 80.26,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0001416,
#     "sensible_heat_load": -0.322,
#     "latent_heat_load": 0.713,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  1",
#     "air_temperature": 83.86,
#     "wall_temperature": 79.82,
#     "humidity_ratio": 0.01655,
#     "heat_transfer_coeff": 0.0009736,
#     "sensible_heat_load": -2.159,
#     "latent_heat_load": 5.983,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  2",
#     "air_temperature": 83.87,
#     "wall_temperature": 79.76,
#     "humidity_ratio": 0.01649,
#     "heat_transfer_coeff": 0.0009736,
#     "sensible_heat_load": -1.97,
#     "latent_heat_load": 5.794,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "2 -  4 -  3",
#     "air_temperature": 83.87,
#     "wall_temperature": 79.62,
#     "humidity_ratio": 0.01638,
#     "heat_transfer_coeff": 0.0009736,
#     "sensible_heat_load": -1.83,
#     "latent_heat_load": 5.654,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "3 -103 -  1",
#     "air_temperature": 87.9,
#     "wall_temperature": 80.1,
#     "humidity_ratio": 0.02021,
#     "heat_transfer_coeff": 0.000246,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "4 -104 -  1",
#     "air_temperature": 87.92,
#     "wall_temperature": 83.72,
#     "humidity_ratio": 0.01913,
#     "heat_transfer_coeff": 0.0001031,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  1",
#     "air_temperature": 88.1,
#     "wall_temperature": 80.6,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0002172,
#     "sensible_heat_load": -0.692,
#     "latent_heat_load": 1.09,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  2",
#     "air_temperature": 88.08,
#     "wall_temperature": 80.87,
#     "humidity_ratio": 0.02013,
#     "heat_transfer_coeff": 0.0002172,
#     "sensible_heat_load": -0.708,
#     "latent_heat_load": 1.106,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "5 -  5 -  3",
#     "air_temperature": 87.4,
#     "wall_temperature": 80.72,
#     "humidity_ratio": 0.0194,
#     "heat_transfer_coeff": 0.0002172,
#     "sensible_heat_load": -0.754,
#     "latent_heat_load": 1.152,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  1",
#     "air_temperature": 82.9,
#     "wall_temperature": 78.65,
#     "humidity_ratio": 0.0155,
#     "heat_transfer_coeff": 0.0009292,
#     "sensible_heat_load": -1.706,
#     "latent_heat_load": 5.331,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  2",
#     "air_temperature": 82.84,
#     "wall_temperature": 78.44,
#     "humidity_ratio": 0.01542,
#     "heat_transfer_coeff": 0.0009292,
#     "sensible_heat_load": -1.779,
#     "latent_heat_load": 5.403,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "6 -  6 -  3",
#     "air_temperature": 83.29,
#     "wall_temperature": 78.69,
#     "humidity_ratio": 0.01561,
#     "heat_transfer_coeff": 0.0009292,
#     "sensible_heat_load": -1.952,
#     "latent_heat_load": 5.577,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "7 -  7 -  1",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.000561,
#     "sensible_heat_load": -81.051,
#     "latent_heat_load": -249.068,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -195.79,
#     "latent_ac": -264.06
#    },
#    {
#     "subsegment_id": "8 -  8 -  1",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 6.37e-05,
#     "sensible_heat_load": 16.331,
#     "latent_heat_load": 7.975,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -6.59,
#     "latent_ac": 7.98
#    },
#    {
#     "subsegment_id": "8 -  8 -  2",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 6.19e-05,
#     "sensible_heat_load": -34.036,
#     "latent_heat_load": -162.702,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -56.95,
#     "latent_ac": -162.7
#    },
#    {
#     "subsegment_id": "9 -  9 -  1",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0006073,
#     "sensible_heat_load": 6.046,
#     "latent_heat_load": -10.78,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -125.14,
#     "latent_ac": -26.91
#    },
#    {
#     "subsegment_id": "9 -  9 -  2",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0004747,
#     "sensible_heat_load": 37.859,
#     "latent_heat_load": 59.653,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -98.1,
#     "latent_ac": 43.43
#    },
#    {
#     "subsegment_id": "9 -  9 -  3",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0004747,
#     "sensible_heat_load": 19.916,
#     "latent_heat_load": 38.984,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -116.75,
#     "latent_ac": 22.69
#    },
#    {
#     "subsegment_id": "9 -  9 -  4",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0004747,
#     "sensible_heat_load": -85.408,
#     "latent_heat_load": -142.324,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -220.53,
#     "latent_ac": -158.53
#    },
#    {
#     "subsegment_id": "10 -110 -  1",
#     "air_temperature": 88.23,
#     "wall_temperature": 87.23,
#     "humidity_ratio": 0.01831,
#     "heat_transfer_coeff": 0.0002044,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "11 - 10 -  1",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 0.0001011,
#     "sensible_heat_load": -26.147,
#     "latent_heat_load": -129.224,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -49.06,
#     "latent_ac": -129.22
#    },
#    {
#     "subsegment_id": "11 - 10 -  2",
#     "air_temperature": 85.0,
#     "wall_temperature": 84.0,
#     "humidity_ratio": 0.01492,
#     "heat_transfer_coeff": 0.0001011,
#     "sensible_heat_load": 24.282,
#     "latent_heat_load": 22.228,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 1.37,
#     "latent_ac": 22.23
#    },
#    {
#     "subsegment_id": "12 - 11 -  1",
#     "air_temperature": 80.0,
#     "wall_temperature": 79.0,
#     "humidity_ratio": 0.01364,
#     "heat_transfer_coeff": 0.0003527,
#     "sensible_heat_load": -428.607,
#     "latent_heat_load": -820.632,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": -550.01,
#     "latent_ac": -835.72
#    },
#    {
#     "subsegment_id": "13 - 12 -  1",
#     "air_temperature": 90.31,
#     "wall_temperature": 82.89,
#     "humidity_ratio": 0.01814,
#     "heat_transfer_coeff": 0.0004685,
#     "sensible_heat_load": 300.514,
#     "latent_heat_load": 7.483,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  2",
#     "air_temperature": 92.22,
#     "wall_temperature": 83.95,
#     "humidity_ratio": 0.0196,
#     "heat_transfer_coeff": 0.0005562,
#     "sensible_heat_load": -2.432,
#     "latent_heat_load": 5.069,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "13 - 12 -  3",
#     "air_temperature": 91.64,
#     "wall_temperature": 82.73,
#     "humidity_ratio": 0.0201,
#     "heat_transfer_coeff": 0.0005562,
#     "sensible_heat_load": -1.799,
#     "latent_heat_load": 4.436,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "14 -114 -  1",
#     "air_temperature": 90.28,
#     "wall_temperature": 81.68,
#     "humidity_ratio": 0.0202,
#     "heat_transfer_coeff": 0.0004081,
#     "sensible_heat_load": 0.0,
#     "latent_heat_load": 0.0,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 13 -  1",
#     "air_temperature": 90.28,
#     "wall_temperature": 81.97,
#     "humidity_ratio": 0.02023,
#     "heat_transfer_coeff": 0.0007594,
#     "sensible_heat_load": -2.661,
#     "latent_heat_load": 6.426,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 13 -  2",
#     "air_temperature": 89.98,
#     "wall_temperature": 81.25,
#     "humidity_ratio": 0.02021,
#     "heat_transfer_coeff": 0.0007594,
#     "sensible_heat_load": -2.343,
#     "latent_heat_load": 6.108,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 14 -  1",
#     "air_temperature": 89.83,
#     "wall_temperature": 78.87,
#     "humidity_ratio": 0.02019,
#     "heat_transfer_coeff": 0.0004426,
#     "sensible_heat_load": -1.612,
#     "latent_heat_load": 3.928,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    },
#    {
#     "subsegment_id": "15 - 14 -  2",
#     "air_temperature": 89.92,
#     "wall_temperature": 78.67,
#     "humidity_ratio": 0.02018,
#     "heat_transfer_coeff": 0.0004426,
#     "sensible_heat_load": -1.599,
#     "latent_heat_load": 3.915,
#     "qwalss": 0.0,
#     "qradss": 0.0,
#     "sensible_ac": 0.0,
#     "latent_ac": 0.0
#    }
#   ]
#  }
# ]

# %%
# second to last pit in normal.inp dataset.  
# last pit [-1] is equivalent to rst file.  this normally does not get
# done after a summary print, but walls and air temps change after a 
# heat sink summary in uncontrolled zones.
# [-2] is pentultimate pit. that matches the last point in time print in
# the normal.out output file.  a little confusing ... i know.
# for most datasets (non-normal operations) you will want the [-1] pit,
# but for comparison to priinted out file, [-2] makes sense in this case

# grab the last pit printed in the output file.
a=my_dataset[-2]
# a should be a dictionary in the normal.inp case and all cases.
# in future if summary objects are added this may change.

print("type of a:",type(a), "\t\tpit time:  ", a['pit'])
# Out:
# type of a: <class 'dict'> 		pit time:   990.0

# %%
# get all the ss data for the last printed pit [-2] for this file
c=a['subsegment_data']
# c should be a list of subsegment-data-dictionaries
print('type of c:',type(c))
# Out:
# type of c: <class 'list'>

# %%
# iterate over ss's and print their ids & temperatures in 'for' loop
for ss in c:
      print("ss_id=  ",ss['subsegment_id'], "\t\tair temperature (deg F)=  ", ss['air_temperature'])
# Out:
# ss_id=   1 -  1 -  1 		air temperature (deg F)=   89.42
# ss_id=   1 -  2 -  1 		air temperature (deg F)=   88.86
# ss_id=   1 -  3 -  1 		air temperature (deg F)=   87.96
# ss_id=   1 -  3 -  2 		air temperature (deg F)=   87.47
# ss_id=   2 -  4 -  1 		air temperature (deg F)=   85.4
# ss_id=   2 -  4 -  2 		air temperature (deg F)=   85.08
# ss_id=   2 -  4 -  3 		air temperature (deg F)=   84.42
# ss_id=   3 -103 -  1 		air temperature (deg F)=   87.64
# ss_id=   4 -104 -  1 		air temperature (deg F)=   89.23
# ss_id=   5 -  5 -  1 		air temperature (deg F)=   87.47
# ss_id=   5 -  5 -  2 		air temperature (deg F)=   87.54
# ss_id=   5 -  5 -  3 		air temperature (deg F)=   86.72
# ss_id=   6 -  6 -  1 		air temperature (deg F)=   83.12
# ss_id=   6 -  6 -  2 		air temperature (deg F)=   81.71
# ss_id=   6 -  6 -  3 		air temperature (deg F)=   80.21
# ss_id=   7 -  7 -  1 		air temperature (deg F)=   78.83
# ss_id=   8 -  8 -  1 		air temperature (deg F)=   85.3
# ss_id=   8 -  8 -  2 		air temperature (deg F)=   85.2
# ss_id=   9 -  9 -  1 		air temperature (deg F)=   78.41
# ss_id=   9 -  9 -  2 		air temperature (deg F)=   78.08
# ss_id=   9 -  9 -  3 		air temperature (deg F)=   77.91
# ss_id=   9 -  9 -  4 		air temperature (deg F)=   78.66
# ss_id=   10 -110 -  1 		air temperature (deg F)=   87.5
# ss_id=   11 - 10 -  1 		air temperature (deg F)=   84.61
# ss_id=   11 - 10 -  2 		air temperature (deg F)=   84.13
# ss_id=   12 - 11 -  1 		air temperature (deg F)=   80.76
# ss_id=   13 - 12 -  1 		air temperature (deg F)=   94.0
# ss_id=   13 - 12 -  2 		air temperature (deg F)=   94.17
# ss_id=   13 - 12 -  3 		air temperature (deg F)=   92.36
# ss_id=   14 -114 -  1 		air temperature (deg F)=   90.77
# ss_id=   15 - 13 -  1 		air temperature (deg F)=   90.64
# ss_id=   15 - 13 -  2 		air temperature (deg F)=   89.95
# ss_id=   15 - 14 -  1 		air temperature (deg F)=   89.79
# ss_id=   15 - 14 -  2 		air temperature (deg F)=   89.74

# %%
# get the section data and print the flows
b=a['section_data']
for section in b:
      print("section_id=  ",section['section_id'], "\t\tair flow rate (cfm)=  ", section['airflow_rate'])
# Out:
# section_id=   1 		air flow rate (cfm)=   37355.3
# section_id=   2 		air flow rate (cfm)=   -319836.3
# section_id=   3 		air flow rate (cfm)=   98071.0
# section_id=   4 		air flow rate (cfm)=   -16955.4
# section_id=   5 		air flow rate (cfm)=   -60715.8
# section_id=   6 		air flow rate (cfm)=   -302880.9
# section_id=   7 		air flow rate (cfm)=   -363596.7
# section_id=   8 		air flow rate (cfm)=   17471.8
# section_id=   9 		air flow rate (cfm)=   -381068.5
# section_id=   10 		air flow rate (cfm)=   -35768.3
# section_id=   11 		air flow rate (cfm)=   53240.1
# section_id=   12 		air flow rate (cfm)=   -327828.3
# section_id=   13 		air flow rate (cfm)=   -327828.3
# section_id=   14 		air flow rate (cfm)=   138177.8
# section_id=   15 		air flow rate (cfm)=   -466006.1
